# %% [markdown]
# # INTERNSHIP PROJECT

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Get the Data
# #### Read in the cars.csv file and set it to a data frame called cars

# %%
cars = pd.read_csv("Data Files/Cars.csv")

# %%
cars
# Out:
#       symboling normalized_losses         make fuel_type aspiration num_doors  \
# 0             3                 ?  alfa-romero       gas        std       two
# 1             3                 ?  alfa-romero       gas        std       two
# 2             1                 ?  alfa-romero       gas        std       two
# 3             2               164         audi       gas        std      four
# 4             2               164         audi       gas        std      four
# 5             2                 ?         audi       gas        std       two
# 6             1               158         audi       gas        std      four
# 7             1                 ?         audi       gas        std      four
# 8             1               158         audi       gas      turbo      four
# 9             0                 ?         audi       gas      turbo       two
# 10            2               192          bmw       gas        std       two
# ...

# %% [markdown]
# #### Check the head of cars

# %%
cars.head()
# Out:
#    symboling normalized_losses         make fuel_type aspiration num_doors  \
# 0          3                 ?  alfa-romero       gas        std       two
# 1          3                 ?  alfa-romero       gas        std       two
# 2          1                 ?  alfa-romero       gas        std       two
# 3          2               164         audi       gas        std      four
# 4          2               164         audi       gas        std      four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# #### To get all the names of the columns

# %%
cars.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'num_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'num_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %% [markdown]
# #### Check the  size of the data

# %%
cars.shape
# Out:
# (2460, 26)

# %% [markdown]
# #### Converting the Categorical data to Numeric Data

# %%
from sklearn.preprocessing import LabelEncoder
le =  LabelEncoder()

# %%
data = cars
data.make = le.fit_transform(data.make)
data.fuel_type = le.fit_transform(data.fuel_type)
data.aspiration = le.fit_transform(data.aspiration)
data.num_doors = le.fit_transform(data.num_doors)
data.body_style = le.fit_transform(data.body_style)
data.drive_wheels = le.fit_transform(data.drive_wheels)
data.engine_location = le.fit_transform(data.engine_location)
data.engine_type = le.fit_transform(data.engine_type)
data.num_cylinders = le.fit_transform(data.num_cylinders)
data.fuel_system= le.fit_transform(data.fuel_system)

# %%
data
# Out:
#       symboling normalized_losses  make  fuel_type  aspiration  num_doors  \
# 0             3                 ?     0          1           0          2
# 1             3                 ?     0          1           0          2
# 2             1                 ?     0          1           0          2
# 3             2               164     1          1           0          1
# 4             2               164     1          1           0          1
# 5             2                 ?     1          1           0          2
# 6             1               158     1          1           0          1
# 7             1                 ?     1          1           0          1
# 8             1               158     1          1           1          1
# 9             0                 ?     1          1           1          2
# 10            2               192     2          1           0          2
# 11            0               192     2          1           0          1
# ...

# %% [markdown]
# #### Check the head of the data

# %%
data.head()
# Out:
#    symboling normalized_losses  make  fuel_type  aspiration  num_doors  \
# 0          3                 ?     0          1           0          2
# 1          3                 ?     0          1           0          2
# 2          1                 ?     0          1           0          2
# 3          2               164     1          1           0          1
# 4          2               164     1          1           0          1
#
#    body_style  drive_wheels  engine_location  wheel_base  ...  engine_size  \
# 0           0             2                0        88.6  ...          130
# 1           0             2                0        88.6  ...          130
# 2           2             2                0        94.5  ...          152
# 3           3             1                0        99.8  ...          109
# 4           3             0                0        99.4  ...          136
#
#    fuel_system  bore  stroke  compression_ratio  horsepower  peak_rpm  \
# ...

# %% [markdown]
# ## Missing Data
# #### Replacing the ? to NaN

# %%
data = data.replace(to_replace="?",value=np.NaN)

# %%
data
# Out:
#       symboling normalized_losses  make  fuel_type  aspiration  num_doors  \
# 0             3               NaN     0          1           0          2
# 1             3               NaN     0          1           0          2
# 2             1               NaN     0          1           0          2
# 3             2               164     1          1           0          1
# 4             2               164     1          1           0          1
# 5             2               NaN     1          1           0          2
# 6             1               158     1          1           0          1
# 7             1               NaN     1          1           0          1
# 8             1               158     1          1           1          1
# 9             0               NaN     1          1           1          2
# 10            2               192     2          1           0          2
# 11            0               192     2          1           0          1
# ...

# %% [markdown]
# ## Data Cleaning
# #### Replacing the NaN values with the Mean of the column

# %%
#from  sklearn.impute import SimpleImputer
from sklearn.preprocessing import Imputer

# %%
imputer= Imputer(missing_values="NaN" , strategy="mean",axis=0)
# Out:
# C:\Users\mamid\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
imputer= imputer.fit(data.iloc[:,:])

# %%
data.iloc[:,:] = imputer.transform(data.iloc[:,:])

# %%
data
# Out:
#       symboling  normalized_losses  make  fuel_type  aspiration  num_doors  \
# 0           3.0              122.0   0.0        1.0         0.0        2.0
# 1           3.0              122.0   0.0        1.0         0.0        2.0
# 2           1.0              122.0   0.0        1.0         0.0        2.0
# 3           2.0              164.0   1.0        1.0         0.0        1.0
# 4           2.0              164.0   1.0        1.0         0.0        1.0
# 5           2.0              122.0   1.0        1.0         0.0        2.0
# 6           1.0              158.0   1.0        1.0         0.0        1.0
# 7           1.0              122.0   1.0        1.0         0.0        1.0
# 8           1.0              158.0   1.0        1.0         1.0        1.0
# 9           0.0              122.0   1.0        1.0         1.0        2.0
# 10          2.0              192.0   2.0        1.0         0.0        2.0
# ...

# %% [markdown]
# #### Changing the type of columns in the data set to int

# %%
data=data.astype(int)
data
# Out:
#       symboling  normalized_losses  make  fuel_type  aspiration  num_doors  \
# 0             3                122     0          1           0          2
# 1             3                122     0          1           0          2
# 2             1                122     0          1           0          2
# 3             2                164     1          1           0          1
# 4             2                164     1          1           0          1
# 5             2                122     1          1           0          2
# 6             1                158     1          1           0          1
# 7             1                122     1          1           0          1
# 8             1                158     1          1           1          1
# 9             0                122     1          1           1          2
# 10            2                192     2          1           0          2
# ...

# %% [markdown]
# ## Data Visualization
# ####  Histogram of the make column

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style('whitegrid')
data['make'].hist(bins=20)
plt.xlabel('car name')
# Out:
# Text(0.5, 0, 'car name')

# %% [markdown]
# #### Creating a Jointplot showing make column versus prices

# %%
sns.jointplot(x='make',y='price',data=data,color='green')

# %% [markdown]
# ## Scale

# %%
from sklearn.preprocessing import scale

# %%
x= data.iloc[:,0:26]
y=data.price

# %%
x=scale(x)
x
# Out:
# C:\Users\mamid\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int32 were all converted to float64 by the scale function.
#   """Entry point for launching an IPython kernel.
# array([[ 1.74347043,  0.        , -1.94825569, ..., -0.64655303,
#         -0.54605874,  0.03667383],
#        [ 1.74347043,  0.        , -1.94825569, ..., -0.64655303,
#         -0.54605874,  0.4194982 ],
#        [ 0.133509  ,  0.        , -1.94825569, ..., -0.95301169,
#         -0.69162706,  0.4194982 ],
#        ...,
#        [-1.47645244, -0.85433189,  1.40664061, ..., -1.10624102,
#         -1.12833203,  1.05456624],
#        [-1.47645244, -0.85433189,  1.40664061, ...,  0.11959362,
#         -0.54605874,  1.18005109],
#        [-1.47645244, -0.85433189,  1.40664061, ..., -0.95301169,
#         -0.83719538,  1.19979744]])

# %%
x = pd.DataFrame(x)
x
# Out:
#             0         1         2         3         4         5         6   \
# 0     1.743470  0.000000 -1.948256  0.328798 -0.469295  1.120713 -3.050975
# 1     1.743470  0.000000 -1.948256  0.328798 -0.469295  1.120713 -3.050975
# 2     0.133509  0.000000 -1.948256  0.328798 -0.469295  1.120713 -0.717207
# 3     0.938490  1.328961 -1.788499  0.328798 -0.469295 -0.826289  0.449677
# 4     0.938490  1.328961 -1.788499  0.328798 -0.469295 -0.826289  0.449677
# 5     0.938490  0.000000 -1.788499  0.328798 -0.469295  1.120713  0.449677
# 6     0.133509  1.139109 -1.788499  0.328798 -0.469295 -0.826289  0.449677
# 7     0.133509  0.000000 -1.788499  0.328798 -0.469295 -0.826289  1.616562
# 8     0.133509  1.139109 -1.788499  0.328798  2.130854 -0.826289  0.449677
# 9    -0.671472  0.000000 -1.788499  0.328798  2.130854  1.120713 -0.717207
# 10    0.938490  2.214935 -1.628742  0.328798 -0.469295  1.120713  0.449677
# ...

# %% [markdown]
# ## K Nearest Neighbors

# %% [markdown]
# #### Split the data into Training set and testing set using train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,random_state=1)

# %% [markdown]
# #### Get the size of all the training and testing data

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1968, 26)
# (492, 26)
# (1968,)
# (492,)

# %% [markdown]
# #### Training the data

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn = KNeighborsClassifier(n_neighbors=7, metric='euclidean')
model_knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#            metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#            weights='uniform')

# %%
model_knn1 = KNeighborsClassifier(n_neighbors=10, metric='euclidean')
model_knn1.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#            metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#            weights='uniform')

# %% [markdown]
# ## Predictions and Evaluations
# #### Now predict values for the testing data

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
y_predict1 = model_knn1.predict(x_test)

# %% [markdown]
# #### Comparing the actual and predicted values

# %%
y_predict1 == y_test
# Out:
# 1268    True
# 2270    True
# 1617    True
# 499     True
# 535     True
# 1457    True
# 1004    True
# 1475    True
# 1167    True
# 477     True
# 2003    True
# 1489    True
# 1791    True
# 1861    True
# 1228    True
# 1959    True
# 2029    True
# 1797    True
# 468     True
# 527     True
# 2040    True
# 1117    True
# 1102    True
# 1347    True
# 2038    True
# 760     True
# 610     True
# 2223    True
# 808     True
# 2220    True
#         ...
# 481     True
# 205     True
# 177     True
# 592     True
# 1599    True
# 1283    True
# 2269    True
# 703     True
# 517     True
# 1957    True
# 839     True
# 2132    True
# 1459    True
# 2345    True
# 165     True
# 16      True
# 1575    True
# 2139    True
# 1448    True
# 1868    True
# 2213    True
# 2344    True
# 1352    True
# 1354    True
# 1426    True
# 1384    True
# 1655    True
# 572     True
# 893     True
# 2204    True
# Name: price, Length: 492, dtype: bool

# %%
np.mean(y_predict1 == y_test)
# Out:
# 0.9857723577235772

# %%
accuracy_score(y_predict1,y_test)
# Out:
# 0.9857723577235772

# %%
confusion_matrix(y_predict1,y_test)
# Out:
# array([[1, 0, 0, ..., 0, 0, 0],
#        [0, 3, 0, ..., 0, 0, 0],
#        [0, 0, 3, ..., 0, 0, 0],
#        ...,
#        [0, 0, 0, ..., 2, 0, 0],
#        [0, 0, 0, ..., 0, 4, 0],
#        [0, 0, 0, ..., 0, 0, 4]], dtype=int64)

# %%
print(classification_report(y_test,y_predict1))
# Out:
#               precision    recall  f1-score   support
#
#         5118       1.00      1.00      1.00         1
#         5151       1.00      1.00      1.00         3
#         5195       1.00      1.00      1.00         3
#         5348       1.00      1.00      1.00         6
#         5389       1.00      1.00      1.00         2
#         5399       1.00      1.00      1.00         4
#         5499       1.00      1.00      1.00         4
#         5572       1.00      1.00      1.00         3
#         6095       1.00      1.00      1.00         2
#         6189       1.00      1.00      1.00         3
#         6229       1.00      1.00      1.00         5
#         6295       1.00      1.00      1.00         2
#         6338       1.00      1.00      1.00         2
#         6377       1.00      1.00      1.00         4
#         6479       1.00      1.00      1.00         3
#         6488       1.00      1.00      1.00         2
# ...

# %%
y_predict = model_knn.predict(x_test)

# %% [markdown]
# #### Comparing the actual and predicted values

# %%
y_predict == y_test
# Out:
# 1268    True
# 2270    True
# 1617    True
# 499     True
# 535     True
# 1457    True
# 1004    True
# 1475    True
# 1167    True
# 477     True
# 2003    True
# 1489    True
# 1791    True
# 1861    True
# 1228    True
# 1959    True
# 2029    True
# 1797    True
# 468     True
# 527     True
# 2040    True
# 1117    True
# 1102    True
# 1347    True
# 2038    True
# 760     True
# 610     True
# 2223    True
# 808     True
# 2220    True
#         ...
# 481     True
# 205     True
# 177     True
# 592     True
# 1599    True
# 1283    True
# 2269    True
# 703     True
# 517     True
# 1957    True
# 839     True
# 2132    True
# 1459    True
# 2345    True
# 165     True
# 16      True
# 1575    True
# 2139    True
# 1448    True
# 1868    True
# 2213    True
# 2344    True
# 1352    True
# 1354    True
# 1426    True
# 1384    True
# 1655    True
# 572     True
# 893     True
# 2204    True
# Name: price, Length: 492, dtype: bool

# %%
np.mean(y_predict == y_test)
# Out:
# 1.0

# %%
accuracy_score(y_predict,y_test)
# Out:
# 1.0

# %%
confusion_matrix(y_predict,y_test)
# Out:
# array([[1, 0, 0, ..., 0, 0, 0],
#        [0, 3, 0, ..., 0, 0, 0],
#        [0, 0, 3, ..., 0, 0, 0],
#        ...,
#        [0, 0, 0, ..., 2, 0, 0],
#        [0, 0, 0, ..., 0, 4, 0],
#        [0, 0, 0, ..., 0, 0, 4]], dtype=int64)

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#         5118       1.00      1.00      1.00         1
#         5151       1.00      1.00      1.00         3
#         5195       1.00      1.00      1.00         3
#         5348       1.00      1.00      1.00         6
#         5389       1.00      1.00      1.00         2
#         5399       1.00      1.00      1.00         4
#         5499       1.00      1.00      1.00         4
#         5572       1.00      1.00      1.00         3
#         6095       1.00      1.00      1.00         2
#         6189       1.00      1.00      1.00         3
#         6229       1.00      1.00      1.00         5
#         6295       1.00      1.00      1.00         2
#         6338       1.00      1.00      1.00         2
#         6377       1.00      1.00      1.00         4
#         6479       1.00      1.00      1.00         3
#         6488       1.00      1.00      1.00         2
# ...
